# %% [markdown]
# ## Análise dos tweets do perfil @jairbolsonaro

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import and check data

# %%
df = pd.read_excel('Jair_Bolsonaro.xlsx')

# %%
df = df[df['Author name']=='Jair M. Bolsonaro']

# %%
df.shape
# Out:
# (1809, 24)

# %%
df.head(1)
# Out:
#           id                                              Title  \
# 0  336912077  - Resumo de nossa ida a Pelotas/RS por ocasião...
#
#                                               Detail  \
# 0  - Resumo de nossa ida a Pelotas/RS por ocasião...
#
#                                                 Link             Source  \
# 0  https://twitter.com/jairbolsonaro/status/11612...  Jair M. Bolsonaro
#
#            Update date         Publish date Sentiment  Ranking Media type  \
# 0  30/09/2019 09:17:00  13/08/2019 08:28:34  Positive       10    twitter
#
#    ...   Reach Interactions Notes        Author name  \
# 0  ...  165120        41447   NaN  Jair M. Bolsonaro
#
#    Author handle (@username)                         Author URL  Gender Age  \
# 0              jairbolsonaro  https://twitter.com/jairbolsonaro    Male NaN
#
#                                                  Bio      City
# 0  Capitão do Exército Brasileiro, eleito 38° Pre...  Brasília
#
# [1 rows x 24 columns]

# %%
# Select columns
cols = ['id', 'Detail', 'Link', 'Update date', 'Publish date', 'Tags', 'Audience', 'Reach', 'Interactions']
df = df[cols]

# %%
def rename_cols(df):
    df.columns = df.columns.str.lower().str.replace(' ', '_')
    return(df)

# %%
df = rename_cols(df)

# %%
text = df.detail

# %% [markdown]
# ### Time series analysis

# %%
df['date'] = pd.to_datetime(df.interactions, format='%d-%m-%Y %H:%M')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     444             try:
# --> 445                 values, tz = conversion.datetime_to_datetime64(arg)
#     446                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslibs/conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'int'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-410ef2a2b016> in <module>
# ----> 1 df['date'] = pd.to_datetime(df.interactions, format='%d-%m-%Y %H:%M')
#
# ~/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     206                 else:
#     207                     kwargs[new_arg_name] = new_arg_value
# --> 208             return func(*args, **kwargs)
#     209
#     210         return wrapper
#
# ~/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     773             result = arg.map(cache_array)
#     774         else:
# --> 775             values = convert_listlike(arg._values, True, format)
#     776             result = arg._constructor(values, index=arg.index, name=arg.name)
#     777     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# ~/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     446                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     447             except (ValueError, TypeError):
# --> 448                 raise e
#     449
#     450     if result is None:
#
# ~/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     411                 try:
#     412                     result, timezones = array_strptime(
# --> 413                         arg, format, exact=exact, errors=errors
#     414                     )
#     415                     if "%Z" in format or "%z" in format:
#
# pandas/_libs/tslibs/strptime.pyx in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '41447' does not match format '%d-%m-%Y %H:%M' (match)

# %%
df.index = df.publish_date

# %%
df.head(1)
# Out:
#                             id  \
# publish_date
# 13/08/2019 08:28:34  336912077
#
#                                                                 detail  \
# publish_date
# 13/08/2019 08:28:34  - Resumo de nossa ida a Pelotas/RS por ocasião...
#
#                                                                   link  \
# publish_date
# 13/08/2019 08:28:34  https://twitter.com/jairbolsonaro/status/11612...
#
#                              update_date         publish_date tags  audience  \
# publish_date
# 13/08/2019 08:28:34  30/09/2019 09:17:00  13/08/2019 08:28:34  NaN   4856491
#
#                       reach  interactions
# publish_date
# 13/08/2019 08:28:34  165120         41447

# %%
plt.figure(figsize=(15, 5))
df.interactions.plot()
sns.despine()

# %% [markdown]
# ### Retweets

# %%
# create column with RT or Tweets from author
df['rt'] = df.detail.str.startswith('RT')

# %%
# rename categories from 'rt' column
rt_dict = {False:'tweet', True:'retweet'}
df.rt = df.rt.map(rt_dict)

# %%
# plot proportion of tweets and rt's
df.rt.value_counts(normalize=True).plot(kind='bar', color='b');
sns.despine()

# %%
# plot number of tweets and rt's
sns.countplot(df.rt)
plt.title('Tweets X Retweets')
plt.xlabel('Number of tweets and retweets')
sns.despine()

# %%
# selecting retweets dataset
retweets = df[df.rt=='retweet']

# %%
# identify who Bolsonaro is retweeting
retweets['rt_author'] = sum([re.findall('RT (@\w+)', i) for i in df.detail], [])
# Out:
# /Users/liviaclarete/.pyenv/versions/dataAnalysis/lib/python3.6/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app

# %%
retweets.rt_author.value_counts()[:10].plot(kind='bar')
sns.despine();
