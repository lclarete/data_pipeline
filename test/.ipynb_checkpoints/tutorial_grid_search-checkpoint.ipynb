# %% [markdown]
# # Tutorial Grid Search Optimization Algorithm
#
# I've got some red pepper flakes up my ass to follow this tutorial :D

# %% [markdown]
# Grid Search Optimization Algorithm in Python: https://stackabuse.com/grid-search-optimization-algorithm-in-python/
#
# Cross Validation and Grid Search for Model Selection in Python: https://stackabuse.com/cross-validation-and-grid-search-for-model-selection-in-python/

# %%
import sys # files
import numpy as np # linear algebra
import pandas as pd # tables

# preprocessing
from sklearn.preprocessing import StandardScaler # normalization
from sklearn.model_selection import train_test_split

# modeling
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasClassifier
from keras.optimizers import Adam
from sklearn.ensemble import RandomForestClassifier

# grid search and cross validation classes
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.model_selection import KFold, StratifiedKFold

# %% [markdown]
# ## CrossValidation X GridSearch
#
#
# * __Grid Search__ is an optimization (automation) algorithm, used for hyperparameter tunning in machine learning.
#
#
# * __CrossValidation__ is intended to minimize the variance problem within a dataset. Sklearn provide a function to split the data into several trains and tests sets called K-Fold Cross-Validation, in which K is any number. K-1 will be used to train the data and the remaining one to test it. The algorithm is trained and then tested K times. Finally, the result of the K-Fold Cross-Validation is the average of the results obtained on each set
#
# ![image.png](https://s3.amazonaws.com/stackabuse/media/cross-validation-grid-search-model-selection-python-1.png)
#
#
#
# In the second fold, SET A, SET B, SET C, and SET D are used for training and SET E is used as testing. The process continues until every set is at least used once for training and once for testing. The final result is the average of results obtained using all folds. This way we can get rid of the variance. Using standard deviation of the results obtained from each fold we can in fact find the variance in the overall result.

# %% [markdown]
# __KFOLD__ is a model validation technique, where it's not using your pre-trained model. Rather, it just use the hyper-parameter and trained a new model with k-1 dataset and test the same model on the kth set.
#
# > K different models are just used for validation
#
# It will return the K different scores (accuracy percentage) which are based on kth test dataset. And we generally take the average to analyse the model.
#
# We repeat this process with all the different models that we want to analyse. Brief Algo:
#
# Preprocessing:
# 1. Split the data into training and test part,
# 2. Trained different models, say SVM, RF, LR on this training data
# > * 2.1: take whole dataset and divide into K-Folds
# > * 2.2: Create a new model with the hyper paramenter received after training on step 1
# > * 2.3: Fit the newly created model on K-1 dataset
# > * 2.4: Test on Kth dataset
# > * 2.5: Take the average score
#
#
# ![image.png](https://tomaszkacmajor.pl/wp-content/uploads/2016/05/cross-validation.png)
#
# Source: https://stackoverflow.com/questions/36063014/what-does-kfold-in-python-exactly-do

# %%
# UNDERSTANDING KFOLD

# define a list from 1 to 12
X = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])
y = np.array([10, 12, 13, 14])

kf = KFold(n_splits=2)
print('Number of folders:', kf.get_n_splits(X))

for train_index, test_index in kf.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
# Out:
# Number of folders: 2
# TRAIN: [2 3] TEST: [0 1]
# TRAIN: [0 1] TEST: [2 3]

# %% [markdown]
# __Difference between Cross Validation (CV), K-Fold Cross Validation (K-Fold CV)__
#
# * K-Fold: multiply k train-test sets instead of 1:
#
# It basically means that  in a k-fold CV, you will train your model k-times and also testing k-times
#
# Source: https://stats.stackexchange.com/questions/405624/difference-between-cross-validation-gridsearchcv-and-does-cross-validation-refer
#
# __Difference between KFold and ShuffleSplit__
#
#
# Source: https://stackoverflow.com/questions/34731421/whats-the-difference-between-kfold-and-shufflesplit-cv

# %% [markdown]
# # Load data

# %%
columns = ['num_pregnant', 'glucose_concentration', 'blood_pressure', 'skin_thickness',
           'serum_insulin', 'BMI', 'pedigree_function', 'age', 'class']

data_path = "https://raw.githubusercontent.com/mkhalid1/Machine-Learning-Projects-Python-/master/Grid%20Search/pima-indians-diabetes.csv"

df = pd.read_csv(data_path, 
                 names=columns,
                 # skip the first rows as it only contains description
                 skiprows=9)

print(df.shape)
df.head(10)
# Out:
# (768, 9)
#    num_pregnant  glucose_concentration  blood_pressure  skin_thickness  \
# 0             6                    148              72              35
# 1             1                     85              66              29
# 2             8                    183              64               0
# 3             1                     89              66              23
# 4             0                    137              40              35
# 5             5                    116              74               0
# 6             3                     78              50              32
# 7            10                    115               0               0
# 8             2                    197              70              45
# 9             8                    125              96               0
#
#    serum_insulin   BMI  pedigree_function  age  class
# 0              0  33.6              0.627   50      1
# 1              0  26.6              0.351   31      0
# 2              0  23.3              0.672   32      1
# 3             94  28.1              0.167   21      0
# 4            168  43.1              2.288   33      1
# 5              0  25.6              0.201   30      0
# 6             88  31.0              0.248   26      1
# 7              0  35.3              0.134   29      0
# 8            543  30.5              0.158   53      1
# 9              0   0.0              0.232   54      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# num_pregnant             768 non-null int64
# glucose_concentration    768 non-null int64
# blood_pressure           768 non-null int64
# skin_thickness           768 non-null int64
# serum_insulin            768 non-null int64
# BMI                      768 non-null float64
# pedigree_function        768 non-null float64
# age                      768 non-null int64
# class                    768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# # Preprocess

# %% [markdown]
# ## Split into X and y variables

# %%
# convert dataframe to numpy array
dataset = df.values

# split data into X and Y
X = dataset[:, 0:8]
y = dataset[:, 8].astype(int)

# %% [markdown]
# ## Split into train and test set
#
# Cross validation replaces the need for train and test set
#
# In this case, the test_size will be 0

# %%
# split into train and test set

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    # the test size was supposed to be 0, but it crashing
    # replaced for 1
    test_size=1
)

# %% [markdown]
# ## Scaling the data the X training data

# %%
# don't do that to y variables
scaler = StandardScaler().fit(X_train)

# transform the X variable
X_standardized = scaler.transform(X_train)

data = pd.DataFrame(X_standardized)
print(data.shape)
data.head()
# Out:
# (767, 8)
#           0         1         2         3         4         5         6  \
# 0  1.232549  1.067033 -0.366053  0.344304  3.603298  0.255414  0.217408
# 1 -0.548918 -0.809633 -0.779623 -0.408601  0.071503 -0.746808  0.837392
# 2 -0.845829 -1.216244 -0.262660 -0.471343  0.132246 -1.368440 -0.169705
# 3 -0.548918 -0.621967 -0.572838  0.908983  0.088858 -1.292322 -0.956027
# 4 -0.548918 -1.028578  0.254302 -0.094890 -0.232214 -0.378904 -0.732227
#
#           7
# 0  1.085427
# 1 -0.955486
# 2 -0.870448
# 3 -0.955486
# 4 -0.955486

# %% [markdown]
# # Modeling

# %%
# Neural Network model

def create_model(learn_rate, dropout_rate):
    # create model
    model = Sequential()
    
    # first layer
    model.add(Dense(8, input_dim=8, 
                    kernel_initializer='normal',
                    activation='relu'
                   ))
    
    # second layer
    model.add(Dropout(dropout_rate))
    
    # third layer
    model.add(Dense(4, 
                    input_dim=8,
                    kernel_initializer='normal'
                   ))
    
    # forth layer
    model.add(Dropout(dropout_rate))
    
    # firth layer:
    # I GUESS: last layer shoudl present the activation function
    model.add(Dense(1, activation='sigmoid'))
    
    # compile the model
    adam = Adam(lr=learn_rate)
    model.compile(loss='binary_crossentropy', 
                  optimizer=adam,
                  metrics=['accuracy'])
    
    return model

# %%
# create the model -- use KerasClassifier when dealing with NN
model = KerasClassifier(build_fn=create_model, verbose=1)

# %%
# random forest classifier
classifier = RandomForestClassifier(n_estimators=300, 
                                    random_state=0)

# %%
# ## Train the model without Grid Search

# # declare the parameters
# dropout_rate = 0.1
# epochs = 1
# batch_size = 20
# learn_rate = 0.001

# # create the model 
# model = create_model(learn_rate, dropout_rate)

# # fit the model
# model.fit(X_train, y_train,
#           batch_size=batch_size,
#           epochs=epochs,
#           verbose=1
#          )

# %% [markdown]
# # Training and cross validation

# %%
all_accuracies = cross_val_score(
    estimator=classifier,
    X=X_train,
    y=y_train,
    cv=5
)

# %%
print(all_accuracies)
print('Mean: ', all_accuracies.mean())
print('Standard deviation: ', all_accuracies.std())
# Out:
# [0.77272727 0.75324675 0.73856209 0.73202614 0.77777778]
# Mean:  0.7548680078091843
# Standard deviation:  0.018078014427431868

# %% [markdown]
# # Grid Search: optimizing Hyper-parameters

# %% [markdown]
# ## Define the parameters

# %%
# KERAS GRID SEARCH
# create a dictionary with the parameters
# define the parameters to be tested using Grid Search
learn_rate = [0.001, 0.02, 0.2]
dropout_rate = [0.0, 0.2, 0.4]
batch_size = [10, 20, 30]
epochs = [1, 2, 3]

seed = 42

# make a dictionary of the grip search parameters
# it may very from each algorithm
param_grid_keras = dict(learn_rate=learn_rate, 
                        dropout_rate=dropout_rate,
                        batch_size=batch_size,
                        epochs=epochs
                       )


# RANDOM FOREST ESTIMATOR
param_grid_rf = {
    'n_estimators': [100, 300, 500, 800, 1000],
    'criterion': ['gini', 'entropy'],
    'bootstrap': [True, False]
}

# %% [markdown]
# ## Initialize the GridSearchCV class

# %%
# grid search for the Random Forest model
grid_rf = GridSearchCV(estimator=classifier,
                       param_grid=param_grid_rf,
                       cv=5,
                       n_jobs=1
                      )

# %%
# build the GridSearchCV for the keras model
grid_keras = GridSearchCV(
    estimator=model, 
    param_grid=param_grid_keras,
    # cross validation
    cv=5,
    # cv=KFold(random_state=seed),
    verbose=10
)

# %% [markdown]
# ## Fit the grid search

# %%
# fit the random forest algorithm
grid_rf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=300, n_jobs=None,
#                                               oob_score=False, random_state=0,
#                                               verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'n_estimators': [100, 300, 500, 800, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
# fit the keras grid search
grid_keras.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV] batch_size=10, dropout_rate=0.0, epochs=1, learn_rate=0.001 .....
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6843 - accuracy: 0.6313
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6615 - accuracy: 0.6429
# [CV]  batch_size=10, dropout_rate=0.0, epochs=1, learn_rate=0.001, score=0.643, total=   1.8s
# [CV] batch_size=10, dropout_rate=0.0, epochs=1, learn_rate=0.001 .....
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.8s remaining:    0.0s
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6843 - accuracy: 0.6052
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6623 - accuracy: 0.6558
# [CV]  batch_size=10, dropout_rate=0.0, epochs=1, learn_rate=0.001, score=0.656, total=   1.9s
# [CV] batch_size=10, dropout_rate=0.0, epochs=1, learn_rate=0.001 .....
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.7s remaining:    0.0s
# 62/62 [==============================] - 0s 3ms/step - loss: 0.7508 - accuracy: 0.5277
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6649 - accuracy: 0.6405
# [CV]  batch_size=10, dropout_rate=0.0, epochs=1, learn_rate=0.001, score=0.641, total=   1.4s
# [CV] batch_size=10, dropout_rate=0.0, epochs=1, learn_rate=0
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.001, score=0.660, total=   1.1s
# [CV] batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.02 ......
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6579 - accuracy: 0.6460
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6444 - accuracy: 0.6558
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.02, score=0.656, total=   2.8s
# [CV] batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.02 ......
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7253 - accuracy: 0.6330
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6438 - accuracy: 0.6558
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.02, score=0.656, total=   1.3s
# [CV] batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.02 ......
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7557 - accuracy: 0.6531
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6570 - accuracy: 0.6405
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.02, score=0.641, total=   1.2s
# [CV] batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.02 ......
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.6270
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6579 - accuracy: 0.6405
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.02, score=0.641, total=   1.3s
# [CV] batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.02 ......
# 62/62 [==============================] - 0s 3ms/step - loss: 0.6719 - accuracy: 0.6368
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6369 - accuracy: 0.6667
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.02, score=0.667, total=   1.4s
# [CV] batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.2 .......
# 62/62 [==============================] - 0s 2ms/step - loss: 1.1079 - accuracy: 0.6166
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6752 - accuracy: 0.6558
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.2, score=0.656, total=   1.6s
# [CV] batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.2 .......
# 62/62 [==============================] - 0s 2ms/step - loss: 2.5640 - accuracy: 0.5808
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6586 - accuracy: 0.6558
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.2, score=0.656, total=   1.2s
# [CV] batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.2 .......
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9028 - accuracy: 0.6189
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6606 - accuracy: 0.6405
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.2, score=0.641, total=   1.1s
# [CV] batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.2 .......
# 62/62 [==============================] - 0s 1ms/step - loss: 0.8513 - accuracy: 0.5928
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6569 - accuracy: 0.6405
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.2, score=0.641, total=   1.0s
# [CV] batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.2 .......
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9570 - accuracy: 0.6270
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6458 - accuracy: 0.6667
# [CV]  batch_size=10, dropout_rate=0.4, epochs=1, learn_rate=0.2, score=0.667, total=   1.1s
# [CV] batch_size=10, dropout_rate=0.4, epochs=2, learn_rate=0.001 .....
# Epoch 1/2
# 62/62 [==============================] - 0s 1ms/step - loss: 0.7133 - accuracy: 0.5971
# Epoch 2/2
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6942 - accuracy: 0.5987
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6558 - accuracy: 0.6558
# [CV]  batch_size=10, dropout_rate=0.4, epochs=2, learn_rate=0.001, score=0.656, total=   1.5s
# [CV] batch_size=10, dropout_rate=0.4, epochs=2, learn_rate=0.001 .....
# Epoch 1/2
# 62/62 [==============================] - 0s 2ms/step - loss: 0.9272 - accuracy: 0.5449
# Epoch 2/2
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7054 - accuracy: 0.5628
# 16/16 [==============================] - 0s 1ms/step - loss: 0.6663 - accuracy: 0.6558
# [CV]  batch_size=10, dropout_rate=0.4, epochs=2, learn_rate=0.001, score=0.656, total=   1.6s
# [CV] batch_size=10, dropout_rate=0.4, epochs=2, learn_rate=0.001 .....
# Epoch 1/2
# 62/62 [==============================] - 0s 2ms/step - loss: 0.7491 - accuracy: 0.5896
# Epoch 2/2
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6687 - accuracy: 0.6319
# 16/16 [==============================] - 0s 2ms/step - loss: 0.6634 - accuracy: 0.6275
# [CV]  batch_size=10, dropout_rate=0.4, epochs=2, learn_rate=0.001, score=0.627, total=   1.3s
# [CV] batch_size=10, dropout_rate=0.4, epochs=2, learn_rate=0.001 .....
# Epoch 1/2
# 62/62 [==============================] - 0s 2ms/step - loss: 0.6892 - accuracy: 0.5961
# Epoch 2/2
# ...
# [CV] batch_size=30, dropout_rate=0.4, epochs=1, learn_rate=0.2 .......
# 21/21 [==============================] - 0s 2ms/step - loss: 1.7522 - accuracy: 0.6319
# 6/6 [==============================] - 0s 3ms/step - loss: 0.6445 - accuracy: 0.6667
# [CV]  batch_size=30, dropout_rate=0.4, epochs=1, learn_rate=0.2, score=0.667, total=   1.7s
# [CV] batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.001 .....
# Epoch 1/2
# 21/21 [==============================] - 0s 2ms/step - loss: 1.2145 - accuracy: 0.5139
# Epoch 2/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7716 - accuracy: 0.5367
# 6/6 [==============================] - 0s 4ms/step - loss: 0.7274 - accuracy: 0.5455
# [CV]  batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.001, score=0.545, total=   1.5s
# [CV] batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.001 .....
# Epoch 1/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8773 - accuracy: 0.5155
# Epoch 2/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7263 - accuracy: 0.5693
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6841 - accuracy: 0.6558
# [CV]  batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.001, score=0.656, total=   1.0s
# [CV] batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.001 .....
# Epoch 1/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8724 - accuracy: 0.5163
# Epoch 2/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6692 - accuracy: 0.6270
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6703 - accuracy: 0.6209
# [CV]  batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.001, score=0.621, total=   1.3s
# [CV] batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.001 .....
# Epoch 1/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.8351 - accuracy: 0.5635
# Epoch 2/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7500 - accuracy: 0.5879
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6697 - accuracy: 0.7124
# [CV]  batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.001, score=0.712, total=   1.1s
# [CV] batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.001 .....
# Epoch 1/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.7851 - accuracy: 0.5456
# Epoch 2/2
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7258 - accuracy: 0.6156
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6823 - accuracy: 0.6601
# [CV]  batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.001, score=0.660, total=   1.0s
# [CV] batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.02 ......
# Epoch 1/2
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7543 - accuracy: 0.5661
# Epoch 2/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6427 - accuracy: 0.6509
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6449 - accuracy: 0.6558
# [CV]  batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.02, score=0.656, total=   1.0s
# [CV] batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.02 ......
# Epoch 1/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6883 - accuracy: 0.6215
# Epoch 2/2
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6516 - accuracy: 0.6509
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6443 - accuracy: 0.6558
# [CV]  batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.02, score=0.656, total=   1.1s
# [CV] batch_size=30, dropout_rate=0.4, epochs=2, learn_rate=0.02 ......
# Epoch 1/2
# 21/21 [==============================] - 0s 1ms/step - loss: 0.
3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6565 - accuracy: 0.6547
# Epoch 3/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6512 - accuracy: 0.6547
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6531 - accuracy: 0.6405
# [CV]  batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.02, score=0.641, total=   1.0s
# [CV] batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.02 ......
# Epoch 1/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6745 - accuracy: 0.6319
# Epoch 2/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6522 - accuracy: 0.6482
# Epoch 3/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6488 - accuracy: 0.6482
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6381 - accuracy: 0.6667
# [CV]  batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.02, score=0.667, total=   1.0s
# [CV] batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.2 .......
# Epoch 1/3
# 21/21 [==============================] - 0s 2ms/step - loss: 2.1974 - accuracy: 0.5954
# Epoch 2/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6673 - accuracy: 0.6509
# Epoch 3/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6506 - accuracy: 0.6509
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6439 - accuracy: 0.6558
# [CV]  batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.2, score=0.656, total=   1.0s
# [CV] batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.2 .......
# Epoch 1/3
# 21/21 [==============================] - 0s 1ms/step - loss: 1.4761 - accuracy: 0.6232
# Epoch 2/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6700 - accuracy: 0.6395
# Epoch 3/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6632 - accuracy: 0.6509
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6454 - accuracy: 0.6558
# [CV]  batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.2, score=0.656, total=   1.1s
# [CV] batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.2 .......
# Epoch 1/3
# 21/21 [==============================] - 0s 2ms/step - loss: 1.1316 - accuracy: 0.6368
# Epoch 2/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6590 - accuracy: 0.6466
# Epoch 3/3
# 21/21 [==============================] - 0s 1ms/step - loss: 0.6735 - accuracy: 0.6173
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6618 - accuracy: 0.6405
# [CV]  batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.2, score=0.641, total=   1.0s
# [CV] batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.2 .......
# Epoch 1/3
# 21/21 [==============================] - 0s 1ms/step - loss: 1.6159 - accuracy: 0.6205
# Epoch 2/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6761 - accuracy: 0.6189
# Epoch 3/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6503 - accuracy: 0.6547
# 6/6 [==============================] - 0s 2ms/step - loss: 0.6542 - accuracy: 0.6405
# [CV]  batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.2, score=0.641, total=   1.0s
# [CV] batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.2 .......
# Epoch 1/3
# 21/21 [==============================] - 0s 2ms/step - loss: 1.8438 - accuracy: 0.6107
# Epoch 2/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6616 - accuracy: 0.6498
# Epoch 3/3
# 21/21 [==============================] - 0s 2ms/step - loss: 0.6752 - accuracy: 0.6368
# 6/6 [==============================] - 0s 1ms/step - loss: 0.6371 - accuracy: 0.6667
# [CV]  batch_size=30, dropout_rate=0.4, epochs=3, learn_rate=0.2, score=0.667, total=   1.1s
# Epoch 1/3
# [Parallel(n_jobs=1)]: Done 405 out of 405 | elapsed:  9.0min finished
# 26/26 [==============================] - 0s 2ms/step - loss: 0.7158 - accuracy: 0.5711
# Epoch 2/3
# 26/26 [==============================] - 0s 1ms/step - loss: 0.6699 - accuracy: 0.6102
# Epoch 3/3
# 26/26 [==============================] - 0s 2ms/step - loss: 0.6574 - accuracy: 0.6415
# GridSearchCV(cv=5, error_score=nan,
#              estimator=<tensorflow.python.keras.wrappers.scikit_learn.KerasClassifier object at 0x149ad9490>,
#              iid='deprecated', n_jobs=None,
#              param_grid={'batch_size': [10, 20, 30],
#                          'dropout_rate': [0.0, 0.2, 0.4], 'epochs': [1, 2, 3],
#                          'learn_rate': [0.001, 0.02, 0.2]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=10)

# %% [markdown]
# ## Analyse the results

# %%
# analyse grid search
def analyse_grid_search(grid_search):
    means = grid_search.cv_results_['mean_test_score']
    stds = grid_search.cv_results_['std_test_score']
    params = grid_search.cv_results_['params']
    
#     results = dict(
#         means=means,
#         stds=stds,
#         params=params
#     )
    best_parameters = grid_search.best_params_
    print(f'Best score: {grid_search.best_score_}')
    print('-----------------------')
    print(f'Best parameters: {grid_search.best_params_}')

# %%
analyse_grid_search(grid_keras)
# Out:
# Best score: 0.6610474586486816
# -----------------------
# Best parameters: {'batch_size': 30, 'dropout_rate': 0.2, 'epochs': 3, 'learn_rate': 0.001}

# %%
analyse_grid_search(grid_rf)
# Out:
# Best score: 0.7692216280451574
# -----------------------
# Best parameters: {'bootstrap': True, 'criterion': 'entropy', 'n_estimators': 100}
